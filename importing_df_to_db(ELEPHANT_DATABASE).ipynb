# %% [markdown]
# <a href="https://colab.research.google.com/github/Nickghase/song_recommender/blob/main/importing_df_to_db(ELEPHANT_DATABASE).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install psycopg2
import psycopg2 as ps
import pandas as pd

# %%
#upload your CSV files here
df = pd.read_csv('preprocessed.csv') 
df.head()
# Out:
#    Unnamed: 0           artist                                      album  \
# 0           0         Aditya A                            Chaand Baaliyan
# 1           1             King                               The Carnival
# 2           2   Tanishk Bagchi        Raataan Lambiyan (From "Shershaah")
# 3           3  Various Artists                  Ranjha (From "Shershaah")
# 4           4           Pritam  Kesariya Audio Teaser (From "Brahmastra")
#
#                                   track_name  popularity  \
# 0                            Chaand Baaliyan          80
# 1                             Tu Aake Dekhle          79
# 2        Raataan Lambiyan (From "Shershaah")          77
# 3                  Ranjha (From "Shershaah")          77
# 4  Kesariya Audio Teaser (From "Brahmastra")          77
#
#                                              img_url  danceability  energy  \
# 0  https://i.scdn.co/image/ab67616d0000b273ec4eca...         0.729   0.396
# 1  https://i.scdn.co/image/ab67616d0000b273e0fc84...         0.770   0.840
# 2  https://i.scdn.co/image/ab67616d0000b273a75c2f...         0.720   0.630
# 3  https://i.scdn.co/image/ab67616d0000b27309426d...         0.603   0.573
# 4  https://i.scdn.co/image/ab67616d0000b273358193...         0.560   0.634
#
#    key  loudness  mode  speechiness  instrumentalness  liveness  valence  \
# 0    0    -8.980     1       0.0359           0.00000    0.1040    0.886
# 1   11    -4.022     1       0.1070           0.00452    0.1450    0.192
# 2   10    -5.549     1       0.0413           0.00000    0.1080    0.512
# 3    1    -5.843     1       0.0502           0.00000    0.0971    0.236
# 4    0    -8.803     1       0.0310           0.00435    0.0983    0.465
#
#     tempo                                          text_data
# 0  97.281           Chaand Baaliyan Aditya A Chaand Baaliyan
# 1  96.012                   Tu Aake Dekhle King The Carnival
# 2  81.009  Raataan Lambiyan (From "Shershaah") Tanishk Ba...
# 3  82.941  Ranjha (From "Shershaah") Various Artists Ranj...
# 4  94.024  Kesariya Audio Teaser (From "Brahmastra") Prit...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1000 non-null   int64
#  1   artist            1000 non-null   object
#  2   album             1000 non-null   object
#  3   track_name        1000 non-null   object
#  4   popularity        1000 non-null   int64
#  5   img_url           1000 non-null   object
#  6   danceability      1000 non-null   float64
#  7   energy            1000 non-null   float64
#  8   key               1000 non-null   int64
#  9   loudness          1000 non-null   float64
#  10  mode              1000 non-null   int64
#  11  speechiness       1000 non-null   float64
#  12  instrumentalness  1000 non-null   float64
#  13  liveness          1000 non-null   float64
#  14  valence           1000 non-null   float64
#  15  tempo             1000 non-null   float64
#  16  text_data         1000 non-null   object
# dtypes: float64(8), int64(4), object(5)
# memory usage: 132.9+ KB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'artist', 'album', 'track_name', 'popularity', 'img_url',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'text_data'],
#       dtype='object')

# %%
df= df.iloc[:,1:18]

# %%
df
# Out:
#               artist                                              album  \
# 0           Aditya A                                    Chaand Baaliyan
# 1               King                                       The Carnival
# 2     Tanishk Bagchi                Raataan Lambiyan (From "Shershaah")
# 3    Various Artists                          Ranjha (From "Shershaah")
# 4             Pritam          Kesariya Audio Teaser (From "Brahmastra")
# ..               ...                                                ...
# 995  Various Artists                                Made For Each Other
# 996       Kumar Sanu         Legendary Hits of Kumar Sanu & Alka Yagnik
# 997  Various Artists                     Bollywood Diva - Madhuri Dixit
# 998      Naseebo Lal  Tere Pyar Ne Kundiyan Paiyaan (Mujra Hi Mujra,...
# 999  Various Artists        Himesh Reshammiya Hits - Aashiqui Mein Teri
#
#                                             track_name  popularity  \
# 0                                      Chaand Baaliyan          80
# 1                                       Tu Aake Dekhle          79
# 2                  Raataan Lambiyan (From "Shershaah")          77
# 3                            Ranjha (From "Shershaah")          77
# 4            Kesariya Audio Teaser (From "Brahmastra")          77
# ..                                                 ...         ...
# 995                           Maine Payal Hai Chhankai           0
# 996     Pehli Baar Dil Yeh (From "Hum Ho Gaye Aap Ke")           0
# 997  Joote De Do Paise Le Lo - From "Hum Aapke Hain...           0
# 998                              Dil Chori Sada Hogaya           0
# 999                               Mujhse Shaadi Karogi           0
#
#                                                img_url  danceability  energy  \
# 0    https://i.scdn.co/image/ab67616d0000b273ec4eca...         0.729   0.396
# 1    https://i.scdn.co/image/ab67616d0000b273e0fc84...         0.770   0.840
# 2    https://i.scdn.co/image/ab67616d0000b273a75c2f...         0.720   0.630
# 3    https://i.scdn.co/image/ab67616d0000b27309426d...         0.603   0.573
# 4    https://i.scdn.co/image/ab67616d0000b273358193...         0.560   0.634
# ..                                                 ...           ...     ...
# 995  https://i.scdn.co/image/ab67616d0000b273426d74...         0.658   0.871
# 996  https://i.scdn.co/image/ab67616d0000b273b9211d...         0.560   0.663
# 997  https://i.scdn.co/image/ab67616d0000b2731a0208...         0.741   0.735
# 998  https://i.scdn.co/image/ab67616d0000b2738224bb...         0.644   0.979
# 999  https://i.scdn.co/image/ab67616d0000b273fec73c...         0.684   0.964
#
#      key  loudness  mode  speechiness  instrumentalness  liveness  valence  \
# 0      0    -8.980     1       0.0359          0.000000    0.1040    0.886
# 1     11    -4.022     1       0.1070          0.004520    0.1450    0.192
# 2     10    -5.549     1       0.0413          0.000000    0.1080    0.512
# 3      1    -5.843     1       0.0502          0.000000    0.0971    0.236
# 4      0    -8.803     1       0.0310          0.004350    0.0983    0.465
# ..   ...       ...   ...          ...               ...       ...      ...
# 995    4    -6.339     1       0.0539          0.002800    0.1920    0.689
# 996    7    -8.797     0       0.0373          0.000023    0.1490    0.952
# 997    2    -9.217     1       0.0493          0.000010    0.3240    0.816
# 998   10    -5.683     0       0.0434          0.021100    0.4150    0.544
# 999    8    -8.513     0       0.1340          0.000032    0.3450    0.696
#
#        tempo                                          text_data
# 0     97.281           Chaand Baaliyan Aditya A Chaand Baaliyan
# 1     96.012                   Tu Aake Dekhle King The Carnival
# 2     81.009  Raataan Lambiyan (From "Shershaah") Tanishk Ba...
# 3     82.941  Ranjha (From "Shershaah") Various Artists Ranj...
# 4     94.024  Kesariya Audio Teaser (From "Brahmastra") Prit...
# ..       ...                                                ...
# 995   90.039  Maine Payal Hai Chhankai Various Artists Made ...
# 996  171.912  Pehli Baar Dil Yeh (From "Hum Ho Gaye Aap Ke")...
# 997  100.492  Joote De Do Paise Le Lo - From "Hum Aapke Hain...
# 998  100.073  Dil Chori Sada Hogaya Naseebo Lal Tere Pyar Ne...
# 999  134.937  Mujhse Shaadi Karogi Various Artists Himesh Re...
#
# [1000 rows x 16 columns]

# %%
# Using ELEPHANT postgress sql
import os
import psycopg2
import urllib.parse

urllib.parse.uses_netloc.append("postgres")
url = urllib.parse.urlparse("postgres://avkkqklv:IRFndtJsWdvqunEfATkCsMlyG-yLo-wE@abul.db.elephantsql.com/avkkqklv")

conn = psycopg2.connect(database=url.path[1:],
  user=url.username,
  password=url.password,
  host=url.hostname,
  port=url.port
)

# %%
curr = conn.cursor()

# %%
"""def connect_to_db(host_name, dbname, port, username, password):
    try:
        conn = ps.connect(host=host_name, database=dbname, user=username, password=password, port=port)

    except ps.OperationalError as e:
        raise e
    else:
        print('Connected!')
        return conn"""

def create_table(curr):
    
    create_table_command = ("""CREATE TABLE IF NOT EXISTS songs (
                    
                    artist VARCHAR(255) NOT NULL,
                    album VARCHAR(255) NOT NULL,
                    track_name VARCHAR(255) ,
                    popularity INTEGER NOT NULL,
                    img_url VARCHAR(255) ,
                    danceability FLOAT  NOT NULL,
                    energy FLOAT NOT NULL,
                    key INTEGER NOT NULL,
                    loudness FLOAT NOT NULL,
                    mode INTEGER NOT NULL,
                    speechiness FLOAT NOT NULL,
                    instrumentalness FLOAT ,
                    liveness FLOAT NOT NULL,
                    valence FLOAT NOT NULL,
                    tempo FLOAT NOT NULL,
                    text_data VARCHAR(255) NOT NULL
                    )""")
            
                    
                    
            
   # conn.commit()
    curr.execute(create_table_command)

def insert_into_table(curr,artist,album,track_name,popularity,img_url,danceability,energy,key,loudness,
                      mode,speechiness,instrumentalness,liveness,valence,tempo,text_data):
    
    insert_into_videos = ("""INSERT INTO songs (artist,album,track_name,popularity,img_url,danceability,energy,key,loudness,
                      mode,speechiness,instrumentalness,liveness,valence,tempo,text_data)
    VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s);""")
    
    row_to_insert = (artist,album,track_name,popularity,img_url,danceability,energy,key,loudness,
                      mode,speechiness,instrumentalness,liveness,valence,tempo,text_data)
    curr.execute(insert_into_videos, row_to_insert)


def append_from_df_to_db(curr,df):
    for i, row in df.iterrows():
        insert_into_table(curr, row['artist'], row['album'], row['track_name'], row['popularity'],row["img_url"]
                          , row['danceability'], row['energy'], row['key'], row['loudness'], row['mode'], row['speechiness'], 
                          row['instrumentalness'], row['liveness'] , row['valence'], row['tempo'],row['text_data'])

# %%
"""
#for AWS PostgressSQL database access


#database credentials
host_name = 'postgres://avkkqklv:IRFndtJsWdvqunEfATkCsMlyG-yLo-wE@abul.db.elephantsql.com/avkkqklv'
dbname = 'abul.db.elephantsql.com (abul-01)'
port = '5432'
username = 'abul.db.elephantsql.com (abul-01)' 
password = 'IRFndtJsWdvqunEfATkCsMlyG-yLo-wE'
conn = None

#establish a connection to db
conn = connect_to_db(host_name, dbname, port, username, password)
curr = conn.cursor() """
# Out:
# "\n#for AWS PostgressSQL database access\n\n\n#database credentials\nhost_name = 'postgres://avkkqklv:IRFndtJsWdvqunEfATkCsMlyG-yLo-wE@abul.db.elephantsql.com/avkkqklv'\ndbname = 'abul.db.elephantsql.com (abul-01)'\nport = '5432'\nusername = 'abul.db.elephantsql.com (abul-01)' \npassword = 'IRFndtJsWdvqunEfATkCsMlyG-yLo-wE'\nconn = None\n\n#establish a connection to db\nconn = connect_to_db(host_name, dbname, port, username, password)\ncurr = conn.cursor() "

# %%
def truncate_table(curr):
    truncate_table = ("""DROP TABLE songs""")
    conn.commit()

    curr.execute(truncate_table)

# %%
#truncate_table(curr)

# %%
#create table

create_table(curr)

# %%
#insert new videos into db table


conn.commit()

# %%
append_from_df_to_db(curr,df)
conn.commit()

# %%
curr.execute("SELECT * FROM songs ")

# %%
records = curr.fetchall()

# %%
song_library = pd.DataFrame(records,columns=df.columns)

# %%
df.columns
# Out:
# Index(['artist', 'album', 'track_name', 'popularity', 'img_url',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'text_data'],
#       dtype='object')

# %%
song_library
# Out:
#               artist                                              album  \
# 0           Aditya A                                    Chaand Baaliyan
# 1               King                                       The Carnival
# 2     Tanishk Bagchi                Raataan Lambiyan (From "Shershaah")
# 3    Various Artists                          Ranjha (From "Shershaah")
# 4             Pritam          Kesariya Audio Teaser (From "Brahmastra")
# ..               ...                                                ...
# 995  Various Artists                                Made For Each Other
# 996       Kumar Sanu         Legendary Hits of Kumar Sanu & Alka Yagnik
# 997  Various Artists                     Bollywood Diva - Madhuri Dixit
# 998      Naseebo Lal  Tere Pyar Ne Kundiyan Paiyaan (Mujra Hi Mujra,...
# 999  Various Artists        Himesh Reshammiya Hits - Aashiqui Mein Teri
#
#                                             track_name  popularity  \
# 0                                      Chaand Baaliyan          80
# 1                                       Tu Aake Dekhle          79
# 2                  Raataan Lambiyan (From "Shershaah")          77
# 3                            Ranjha (From "Shershaah")          77
# 4            Kesariya Audio Teaser (From "Brahmastra")          77
# ..                                                 ...         ...
# 995                           Maine Payal Hai Chhankai           0
# 996     Pehli Baar Dil Yeh (From "Hum Ho Gaye Aap Ke")           0
# 997  Joote De Do Paise Le Lo - From "Hum Aapke Hain...           0
# 998                              Dil Chori Sada Hogaya           0
# 999                               Mujhse Shaadi Karogi           0
#
#                                                img_url  danceability  energy  \
# 0    https://i.scdn.co/image/ab67616d0000b273ec4eca...         0.729   0.396
# 1    https://i.scdn.co/image/ab67616d0000b273e0fc84...         0.770   0.840
# 2    https://i.scdn.co/image/ab67616d0000b273a75c2f...         0.720   0.630
# 3    https://i.scdn.co/image/ab67616d0000b27309426d...         0.603   0.573
# 4    https://i.scdn.co/image/ab67616d0000b273358193...         0.560   0.634
# ..                                                 ...           ...     ...
# 995  https://i.scdn.co/image/ab67616d0000b273426d74...         0.658   0.871
# 996  https://i.scdn.co/image/ab67616d0000b273b9211d...         0.560   0.663
# 997  https://i.scdn.co/image/ab67616d0000b2731a0208...         0.741   0.735
# 998  https://i.scdn.co/image/ab67616d0000b2738224bb...         0.644   0.979
# 999  https://i.scdn.co/image/ab67616d0000b273fec73c...         0.684   0.964
#
#      key  loudness  mode  speechiness  instrumentalness  liveness  valence  \
# 0      0    -8.980     1       0.0359          0.000000    0.1040    0.886
# 1     11    -4.022     1       0.1070          0.004520    0.1450    0.192
# 2     10    -5.549     1       0.0413          0.000000    0.1080    0.512
# 3      1    -5.843     1       0.0502          0.000000    0.0971    0.236
# 4      0    -8.803     1       0.0310          0.004350    0.0983    0.465
# ..   ...       ...   ...          ...               ...       ...      ...
# 995    4    -6.339     1       0.0539          0.002800    0.1920    0.689
# 996    7    -8.797     0       0.0373          0.000023    0.1490    0.952
# 997    2    -9.217     1       0.0493          0.000010    0.3240    0.816
# 998   10    -5.683     0       0.0434          0.021100    0.4150    0.544
# 999    8    -8.513     0       0.1340          0.000032    0.3450    0.696
#
#        tempo                                          text_data
# 0     97.281           Chaand Baaliyan Aditya A Chaand Baaliyan
# 1     96.012                   Tu Aake Dekhle King The Carnival
# 2     81.009  Raataan Lambiyan (From "Shershaah") Tanishk Ba...
# 3     82.941  Ranjha (From "Shershaah") Various Artists Ranj...
# 4     94.024  Kesariya Audio Teaser (From "Brahmastra") Prit...
# ..       ...                                                ...
# 995   90.039  Maine Payal Hai Chhankai Various Artists Made ...
# 996  171.912  Pehli Baar Dil Yeh (From "Hum Ho Gaye Aap Ke")...
# 997  100.492  Joote De Do Paise Le Lo - From "Hum Aapke Hain...
# 998  100.073  Dil Chori Sada Hogaya Naseebo Lal Tere Pyar Ne...
# 999  134.937  Mujhse Shaadi Karogi Various Artists Himesh Re...
#
# [1000 rows x 16 columns]
